# %% [markdown]
# # Subject 02

# %%
# loading data
# %run EEG_auxiliary_module.ipynb
# %matplotlib inline
import mne
epochs = mne.read_epochs('F:/EEG_analysis/S02_perc-epo.fif')
epochs = block_average(epochs, 4, 11, kind='perc')

# %% [markdown]
# ### Plot by conditions

# %%
plot_coef_by_cond(epochs)
# Out:
# Progress: [####################] 100.0%
#  The duration is 0.1 minutes

# %% [markdown]
# ### Plot across conditions

# %%
plot_coef_all(epochs)
# Out:
# Progress: [####################] 100.0%
#  The duration is 1.8 minutes

# %% [markdown]
# # Subject 03

# %%
# loading data
# %run EEG_auxiliary_module.ipynb
# %matplotlib inline
import mne
epochs = mne.read_epochs('F:/EEG_analysis/S03_perc-epo.fif')
epochs = block_average(epochs, 4, 12, kind='perc')

# %% [markdown]
# ### Plot by condition

# %%
plot_coef_by_cond(epochs)
# Out:
# Progress: [####################] 100.0%
#  The duration is 0.1 minutes

# %% [markdown]
# ### Plot across conditions

# %%
plot_coef_all(epochs)
# Out:
# Progress: [####################] 100.0%
#  The duration is 2.3 minutes

# %% [markdown]
# # Subject 04

# %%
# loading data
# %run EEG_auxiliary_module.ipynb
# %matplotlib inline
import mne
epochs = mne.read_epochs('F:/EEG_analysis/S04_perc-epo.fif')
epochs = block_average(epochs, 4, 12, kind='perc')

# %% [markdown]
# ### Plot by condition

# %%
plot_coef_by_cond(epochs)
# Out:
# Progress: [####################] 100.0%
#  The duration is 0.1 minutes

# %% [markdown]
# ### Plot across conditions

# %%
plot_coef_all(epochs)
# Out:
# Progress: [####################] 100.0%
#  The duration is 2.2 minutes
